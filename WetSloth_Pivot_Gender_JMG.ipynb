# %%
import pandas as pd
import numpy as np
import os
import csv
from csv import DictReader
from collections import Counter
import re 
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
csv_path =  "abc.csv"
Top_Hits_df = pd.read_csv(csv_path, sep= '\t', encoding='utf-8')
Top_Hits_df
# Out:
#      Ranking                     Artist                        Song Title  \
# 0          1                Percy Faith       Theme From “A Summer Place”
# 1          2                 Jim Reeves                  He’ll Have To Go
# 2          3            Everly Brothers                     Cathy’s Clown
# 3          4             Johnny Preston                      Running Bear
# 4          5               Mark Dinning                        Teen Angel
# 5          6                 Brenda Lee                         I’m Sorry
# 6          7              Elvis Presley                 It’s Now Or Never
# 7          8                Jimmy Jones                         Handy Man
# 8          9              Elvis Presley                      Stuck On You
# 9         10             Chubby Checker                         The Twist
# 10         1                Bobby Lewis               Tossin’ And Turnin’
# 11         2                Patsy Cline                  I Fall To Pieces
# ...

# %%
#Top_Hits_df["Song Title"].value_counts()

# %%
# words = ['she', "her", "woman", "women", "gal", "girl", "chick", "lady", "ladies", 
#           "he", "his", "man", "men", "pal", "boy", "guy", "dude", "gentleman", "gentlemen"]

# for word in words:
#      print('{} : {}'.format(word, Top_Hits_df['Song Title'].str.lower().str.contains(word).sum()))

# %%
# for row in Top_Hits_df:
#       if str(words) in row[3]:
#         print("row")

# %%
# Top_Hits = [i for i in DictReader(Top_Hits_df, delimiter=',')]

# search("she")

# def search(criteria):
#     for row in Top_Hits:
#         for data in row.values():
#             if criteria in data:
#                 print(row)
                
# # search("she")

# %%
# Top_Hits_df['Song Title'].value_counts()

# %%
# song_words = re.compile('\s*\w*\s')

Songs = Top_Hits_df['Song Title'].tolist()
# # so = re.findall(, Songs, re.MULTILINE)
print(Songs)
# Out:
# ['Theme From “A Summer Place”', 'He’ll Have To Go', 'Cathy’s Clown', 'Running Bear', 'Teen Angel', 'I’m Sorry', 'It’s Now Or Never', 'Handy Man', 'Stuck On You', 'The Twist', 'Tossin’ And Turnin’', 'I Fall To Pieces', 'Michael', 'Cryin’', 'Runaway', 'My True Story', 'Pony Time', 'Wheels', 'Raindrops', 'Wooden Heart (Muss I Denn)', 'Stranger On The Shore', 'I Can’t Stop Loving You', 'Mashed Potato Time', 'Roses Are Red', 'The Stripper', 'Johnny Angel', 'The Loco-Motion', 'Let Me In', 'The Twist', 'Soldier Boy', 'Sugar Shack', 'Surfin’ U.S.A.', 'The End Of The World', 'Rhythm Of The Rain', 'He’s So Fine', 'Blue Velvet', 'Hey Paula', 'Fingertips II', 'Washington Square', 'It’s All Right', 'I Want To Hold Your Hand', 'She Loves You', 'Hello, Dolly!', 'Oh, Pretty Woman', 'I Get Around', 'Everybody Loves Somebody', 'My Guy', 'We’ll Sing In The Sunshine', 'Last Kiss', 'Where Did Our Love Go', 'Wooly Bully', 'I Can’t Help Myself (Sugar Pie Honey Bunch)', '(I Can’t Get No) Satisfaction', 'You
# ...

# %%
Song_Title = Top_Hits_df['Song Title']
Song_Title
Title = len(Song_Title)

# %%
# len(set(Song_Title))

# %%
# Counter(Song_Title).keys() # equals to list(set(words))
# Counter(Song_Title).values() # counts the elements' frequency

# %%
# Song_Title_Word_Count = Song_Title.str.split(expand=True).stack().value_counts()
# Song_Title_Word_Count.count()

# %%
# Female_Counter = []
# Male_Counter = []


# Female_Words = ["She", "Queen", "Woman", "Women", "Gal", "Girl", 
#                 "Chick", "Lady", "Ladies"] 
          
# Male_Words = ["He", "His", "Man", "Men", 
#               "Boy", "Guy", "Gentleman", 
#               "Gentlemen", "King"]


# z = 0 
# for song in Songs:
# #      print('{} : {}'.format(word, Top_Hits_df['Song Title'].str.lower().str.contains(word).sum()))
# #     print(x) 
#     for word in Female_Words: 
#         if song == Female_Words[z]:
         
#             print(Female_Words[z])
# #         Female_Counter.append(Female_words[z])
# #         print(word)
# #     elif word in sound matches Male_words: 
# #         do this 
#     #print(Song_Title)
#     #print(z)
# #     else:
# #             Female_Counter[word]=0

# # print(Female_Counter)

# %%
# for song in Songs:
#     for word in Female_Words:
#         if word in song:
#             print(word)

# %%
Female_Words = ["She", "Queen", "Woman", "Women", "Gal", "Girl", 
                "Chick", "Lady", "Ladies", "Gurls", "Sister", "Wife", "Daughter"] 
          

f=0

Female_Counter = []

for song in Songs:
    if Female_Words[0] in song:
        Female_Counter.append(Female_Words[0])
        f = f + 1
        print(song)
    if Female_Words[1] in song:
        Female_Counter.append(Female_Words[1])
        f = f + 1
        print(song)
    if Female_Words[2] in song:
        Female_Counter.append(Female_Words[2])
        f = f + 1
        print(song)
    if Female_Words[3] in song:
        print(song)
        f = f + 1
        Female_Counter.append(Female_Words[3])
    if Female_Words[4] in song:
        print(song)
        f = f + 1
        Female_Counter.append(Female_Words[4])
    if Female_Words[5] in song:
        print(song)
        Female_Counter.append(Female_Words[5])
        f = f + 1
        print(song)
    if Female_Words[6] in song:
        Female_Counter.append(Female_Words[6])
        f = f + 1
        print(song)
    if Female_Words[7] in song:
        Female_Counter.append(Female_Words[7])
        f = f + 1
        print(song)
    if Female_Words[8] in song:
        Female_Counter.append(Female_Words[8])
        f = f + 1
        print(song)
    if Female_Words[9] in song:
        Female_Counter.append(Female_Words[9])
        f = f + 1
        print(song)
    if Female_Words[9] in song:
        Female_Counter.append(Female_Words[10])
        f = f + 1
        print(song)
    if Female_Words[9] in song:
        Female_Counter.append(Female_Words[11])
        f = f + 1
        print(song)
    if Female_Words[9] in song:
        Female_Counter.append(Female_Words[12])
        f = f + 1
        print(song)
        
print(f)
print(Female_Counter)
# Out:
# She Loves You
# Oh, Pretty Woman
# My Girl
# My Girl
# Honky Tonk Women
# American Woman / No Sugar Tonight
# Go Away Little Girl
# Go Away Little Girl
# One Hell Of A Woman
# Disco Lady
# Three Times A Lady
# Bad Girls
# Bad Girls
# Lady
# Jessie’s Girl
# Jessie’s Girl
# Girl You Know Its True
# Girl You Know Its True
# All That She Wants
# Independent Women Part I
# Hollaback Girl
# Hollaback Girl
# Big Girls Don’t Cry
# Big Girls Don’t Cry
# Single Ladies (Put A Ring On It)
# California Gurls
# California Gurls
# California Gurls
# California Gurls
# Trap Queen
# 23
# ['She', 'Woman', 'Girl', 'Women', 'Woman', 'Girl', 'Woman', 'Lady', 'Lady', 'Girl', 'Lady', 'Girl', 'Girl', 'She', 'Women', 'Girl', 'Girl', 'Ladies', 'Gurls', 'Sister', 'Wife', 'Daughter', 'Queen']

# %%
Male_Words = ["He", "His", "Man", "Men", 
              "Boy", "Guy", "Gentleman", 
              "Gentlemen", "King", "Brother", "Father", "Son"]

m=0

Male_Counter = []

for song in Songs:
    if Male_Words[0] in song:
        m = m + 1
        Male_Counter.append(Male_Words[0])
        print(song)
    if Male_Words[1] in song:
        m = m + 1
        Male_Counter.append(Male_Words[1])
        print(song)
    if Male_Words[2] in song:
        f = f + 1
        Male_Counter.append(Male_Words[2])
        print(song)
    if Male_Words[3] in song:
        m = m + 1
        Male_Counter.append(Male_Words[3])
    if Male_Words[4] in song:
        m = m + 1
        Male_Counter.append(Male_Words[4])
    if Male_Words[5] in song:
        m = m + 1
        Male_Counter.append(Male_Words[5])
    if Male_Words[6] in song:
        m = m + 1
        Male_Counter.append(Male_Words[6])
    if Male_Words[7] in song:
        f = f + 1
        Male_Counter.append(Male_Words[7])
    if Male_Words[8] in song:
        m = m + 1
        Male_Counter.append(Male_Words[8])
    if Male_Words[8] in song:
        m = m + 1
        Male_Counter.append(Male_Words[9])
    if Male_Words[8] in song:
        m = m + 1
        Male_Counter.append(Male_Words[10])
    if Male_Words[8] in song:
        m = m + 1
        Male_Counter.append(Male_Words[11])
        
        
        
print(m)
print(Male_Counter)
# Out:
# He’ll Have To Go
# Handy Man
# Wooden Heart (Muss I Denn)
# He’s So Fine
# Hey Paula
# Hello, Dolly!
# I Can’t Help Myself (Sugar Pie Honey Bunch)
# Help!
# Can’t You Hear My Heartbeat
# Hey Jude
# Raindrops Keep Fallin’ On My Head
# How Can You Mend A Broken Heart
# Candy Man
# Killing Me Softly With His Song
# One Hell Of A Woman
# Don’t Go Breaking My Heart
# Total Eclipse Of The Heart
# Maneater
# Maniac
# Hello
# Owner Of A Lonely Heart
# Burning Heart
# Here I Go Again
# Heaven Is A Place On Earth
# Hands To Heaven
# Cold Hearted
# Tears In Heaven
# Can’t Help Falling In Love
# Hero
# Un-Break My Heart
# Heartbreak Hotel
# Nobody’s Supposed To Be Here
# He Wasn’t Man Enough
# He Wasn’t Man Enough
# Hot in Herre
# Hey Ya!
# Before He Cheats
# Hey There Delilah
# Heartless
# Gives You Hell
# Hey, Soul Sister
# Break Your Heart
# Hello
# 45
# ...

# %%
# q=0

# if "He" in [Songs]:
#     q = q + 1

# print(q)

# %%
# Female = []

# Female_Words = ["she", "she'll", "she's", "she'd", "her", "hers", 
#                 "Queen", "woman", "women", "gal", "girl", "girls", 
#                 "chick", "chicks", "lady", "ladies"] 

# for word in Female_Words:
#        if word in Song_Title:
# #             word_count = Song_Title.count(word)
#             Female.update((word))
    
# print(Female)

# %%
# df.song_title.apply(lambda x: checkTitle(x, Female_Words))

# "in" in "The cat jumped in a hat" #True
# "in" in ["the", 'cat', 'jumped', 'in', 'hat'] #True

# def titlesearch(songs, Female_Words): 
#     for song in Songs:
#         if song == Female_Words:
#             print("true")

# Top_Hits_df.Song Title.apply(lambda x: )
#  print(Songs)

# %%
# Female_Words = ["she", "she'll", "she's", "she'd", "her", "hers", 
#                 "Queen", "woman", "women", "gal", "girl", "girls", 
#                 "chick", "chicks", "lady", "ladies"] 

# count = Counter()
# for Female_Words in Song_Title:
#     count[Female_Words] += 1
    
# print(count)

# %%
String = ' '.join(Top_Hits_df['Song Title'].tolist())
String
# Out:
# 'Theme From “A Summer Place” He’ll Have To Go Cathy’s Clown Running Bear Teen Angel I’m Sorry It’s Now Or Never Handy Man Stuck On You The Twist Tossin’ And Turnin’ I Fall To Pieces Michael Cryin’ Runaway My True Story Pony Time Wheels Raindrops Wooden Heart (Muss I Denn) Stranger On The Shore I Can’t Stop Loving You Mashed Potato Time Roses Are Red The Stripper Johnny Angel The Loco-Motion Let Me In The Twist Soldier Boy Sugar Shack Surfin’ U.S.A. The End Of The World Rhythm Of The Rain He’s So Fine Blue Velvet Hey Paula Fingertips II Washington Square It’s All Right I Want To Hold Your Hand She Loves You Hello, Dolly! Oh, Pretty Woman I Get Around Everybody Loves Somebody My Guy We’ll Sing In The Sunshine Last Kiss Where Did Our Love Go Wooly Bully I Can’t Help Myself (Sugar Pie Honey Bunch) (I Can’t Get No) Satisfaction You Were On My Mind You’ve Lost That Lovin’ Feelin’ Downtown Help! Can’t You Hear My Heartbeat Crying In The Chapel My Girl The Ballad Of The Green Berets Cherish 
# ...

# %%
# # z = 0
# if set(Female_Words).intersection(String.split()):
#     z = z + 1
    
# print(z)

# %%
# z = 0

# for word in Female_Words:
#     if word in String:
#         z = z + 1
        
#         print(word)

# %%
# "She", "Queen", "Woman", "Women", "Gal", "Girl", 
#                 "Chick", "Lady", "Ladies"

# %%
She = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("She"), String))
Queen = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Queen"), String))   
Woman = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Woman"), String))
Women = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Women"), String))
Gal = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Gal"), String))
Girl = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Girl"), String))
Girls = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Girls"), String))
Gurls = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Gurls"), String))
Chick = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Chick"), String))
Lady = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Lady"), String))
Ladies = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Ladies"), String))
Sister = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Sister"), String))
Wife = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Wife"), String))
Daughter = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Daughter"), String))

Female_Sum = (She + Queen + Woman + Women + Gal + Girl + Gurls + Chick + Lady + Ladies + Sister + Wife + Daughter)
Female_Sum
# Out:
# 19

# %%
# "He", "His", "Man", "Men", 
#               "Boy", "Guy", "Gentleman", 
#               "Gentlemen", "King", "Brother", "Father", "Son", "Boys",

# %%
He = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("He"), String))
His = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("His"), String))   
Man = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Man"), String))
Men = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Men"), String))
Boy = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Boy"), String))
Boys = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Boys"), String))
Guy = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Guy"), String))
Gentlemen = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Gentlemen"), String))
Gentleman = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Gentleman"), String))
King = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("King"), String))
Brother = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Brother"), String))
Father = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Father"), String))
Son = sum(1 for _ in re.finditer(r'\b%s\b' % re.escape("Son"), String))

Male_Sum = (He + His + Man + Men + Boy + Boys + Guy + Gentleman + Gentleman + King + Brother + Father + Son)
Male_Sum
# Out:
# 14

# %%
Male_P = Male_Sum / Title * 100
Female_P = Female_Sum / Title * 100
All_P = Title / Title * 100

# %%
Gender_df = pd.DataFrame({
    "Song Titles":["All Songs", "Male Songs", "Female Songs"], 
    "Total Number":[Title, Male_Sum, Female_Sum], 
    "Percent of Songs": [All_P, Male_P, Female_P]})

Gender_df["Percent of Songs"] = Gender_df["Percent of Songs"].map("{:.2f}%".format)

Gender_Title = Gender_df[["Song Titles", "Total Number", "Percent of Songs"]]

Gender_Title
# Out:
#     Song Titles  Total Number Percent of Songs
# 0     All Songs           580          100.00%
# 1    Male Songs            14            2.41%
# 2  Female Songs            19            3.28%

# %%
Titles = ('Total', 'Male', 'Female')
y_pos = np.arange(len(Titles))
Sums = [Title, Male_Sum, Female_Sum]
 
plt.bar(y_pos, Sums, align='center', alpha=0.5)
plt.xticks(y_pos, Titles)
plt.ylabel('Number of Songs')
plt.title('Total Song Titles vs Gender Specific Song Titles')
# Out:
# Text(0.5,1,'Total Song Titles vs Gender Specific Song Titles')
